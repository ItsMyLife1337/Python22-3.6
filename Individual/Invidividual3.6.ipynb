# %% [markdown]
# ## Создать ноутбук, в котором выполнить решение вычислительной задачи (например, задачи из области физики, экономики, математики, статистики и т. д.) требующей построения трехмерного графика.

# %% [markdown]
# Один из примеров вычислительной задачи, которая требует построения трехмерного графика, может быть задача оптимизации. Например, предположим, что у нас есть функция двух переменных f(x,y), которая представляет собой затраты на производство продукта в зависимости от количества используемых сырьевых материалов x и y. Цель: найти минимальные затраты на производство продукта.

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# %%
# Определение функции затрат
def f(x, y):
    return x**2 + y**2

# %%
# Вычисление градиента функции затрат
def grad_f(x, y):
    return np.array([2*x, 2*y])

# %%
# Параметры градиентного спуска
alpha = 0.1 # шаг обучения
n_iter = 100 # максимальное число итераций

# Начальные значения x и y
x = 5
y = 5

# %%
# Градиентный спуск
for i in range(n_iter):
    grad = grad_f(x, y)
x -= alpha * grad[0]
y -= alpha * grad[1]

# %%
# Вывод результатов
print(f"Минимальные затраты: {f(x,y)} при x={x} и y={y}")
# Out:
# Минимальные затраты: 32.0 при x=4.0 и y=4.0

# %%
# Создание 3D-подграфика
fig = plt.figure()
ax = plt.axes(projection='3d')

# Создание данных для построения графика
x_vals = np.linspace(-6, 6, 30)
y_vals = np.linspace(-6, 6, 30)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# Построение поверхности
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')
ax.set_title('График функции затрат')
plt.show()
